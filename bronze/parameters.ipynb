# %%
datasets = [
    {
        "file_name":"products"
    },
    {
        "file_name":"orders"
    },
    {
        "file_name":"order_items"
    },
    {
        "file_name":"merchants"
    },
    {
        "file_name":"customers"
    }
]

# %%
dbutils.jobs.taskValues.set("output_datasets", datasets)
